# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
cd My\ Drive
# Out:
# /gdrive/My Drive

# %%
cd Colab\ Notebooks
# Out:
# /gdrive/My Drive/Colab Notebooks

# %%
cd SIH\ ML\ Model
# Out:
# /gdrive/My Drive/Colab Notebooks/SIH ML Model

# %%
dataset = pd.read_csv("new.csv")

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1167995 entries, 0 to 1167994
# Data columns (total 12 columns):
# id              1167995 non-null int64
# ip              1167995 non-null object
# proxy_type      1167995 non-null object
# country_code    1167911 non-null object
# country_name    1167995 non-null object
# region          1167995 non-null object
# city            1167995 non-null object
# isp             1167992 non-null object
# domain          1167995 non-null object
# used_as         1167995 non-null object
# as_no           1167995 non-null object
# as_name         1167995 non-null object
# dtypes: int64(1), object(11)
# memory usage: 106.9+ MB

# %%
print(dataset.size)
# Out:
# 14015940

# %%
dataset = np.asarray(dataset)

# %%
dataset[:,2]
# Out:
# array(['PUB', 'PUB', 'PUB', ..., 'PUB', 'PUB', 'PUB'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
dataset[:,2] = encoder.fit_transform(dataset[:,2])

# %%
dataset[:,2]
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=object)

# %%
data = pd.read_csv("new.csv")
data.proxy_type.unique()
# Out:
# array(['PUB'], dtype=object)
